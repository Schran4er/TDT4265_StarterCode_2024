# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import glob, os

plt.style.use(
    ["mystyle.mplstyle", "PROCI_mod.mplstyle"]
)

# %%
from cycler import cycler
plt.rcParams["axes.prop_cycle"] = cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'])
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
dints = pd.read_csv("dints/model_fold0/accuracy_history.csv", delim_whitespace=True)
segres = pd.read_csv("segresnet/model/accuracy_history.csv", delim_whitespace=True)
dints_wPre = pd.read_csv("with_pretrain/ASOCA/dints/model_fold0/accuracy_history.csv", delim_whitespace=True)
segres_wPre = pd.read_csv("with_pretrain/ASOCA/segresnet/model/accuracy_history.csv", delim_whitespace=True)

# %%
dints = pd.read_csv("dints/model_fold0/accuracy_history.csv", delim_whitespace=True)
segres = pd.read_csv("segresnet/model/accuracy_history.csv", delim_whitespace=True)
dints_wPre = pd.read_csv("with_pretrain/ASOCA/dints/model_fold0/accuracy_history.csv", delim_whitespace=True)
segres_wPre = pd.read_csv("with_pretrain/ASOCA/segresnet/model/accuracy_history.csv", delim_whitespace=True)


plt.plot(segres.index, segres.metric, c = colors[0])        # naming wrong in pandas
plt.plot(dints.epoch, dints.loss, c = colors[1])
plt.plot(segres_wPre.index, segres_wPre.metric, c = colors[0], linestyle=":")
plt.plot(dints_wPre.epoch, dints_wPre.loss, c = colors[1], linestyle=":")
plt.xlabel("epochs")
plt.ylabel("training loss")
plt.xlim(0, 250)

plt.legend(["Model A (segresnet)", "Mode B (dints)", "Model A with Pretrain", "Model B with Pretrain"])
plt.savefig("traing_loss.pdf")

# %%
plt.plot(segres.index, segres.epoch, c = colors[0])        # naming wrong in pandas
plt.plot(dints.epoch, dints.metric,c = colors[1])
plt.plot(segres_wPre.index, segres_wPre.epoch, ":", c = colors[0])        # naming wrong in pandas
plt.plot(dints_wPre.epoch, dints_wPre.metric, ":", c = colors[1])
plt.xlabel("epochs")
plt.ylabel("training accuracy")
plt.xlim(0, 250)

plt.legend(["Model A (segresnet)", "Mode B (dints)", "Model A with Pretrain", "Model B with Pretrain"])
plt.savefig("traing_acc.pdf")
